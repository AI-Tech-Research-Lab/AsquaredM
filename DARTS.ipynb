# %%
#Setup

# %%
# !sh scripts/darts-nasbench-search.sh
# Out:
# Experiment dir : results/nasbench_search_datasetcifar10_betadecayFalse_unrolledTrue_data_augTrue_samFalse_rho_alpha_sam1e-3_seed1
# 10/14 09:46:00 AM gpu device = 0
# ...

# %%
# !sh scripts/betadarts-nasbench-search.sh
# Out:
# Experiment dir : results/nasbench_search_datasetcifar10_betadecayTrue_unrolledFalse_data_augTrue_samFalse_rho_alpha_sam1e-6_seed1
# 10/13 06:28:42 PM gpu device = 0
# ...
